# %%
import numpy as np
import lab3
from importlib import reload
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
reload(lab3)
X1 = np.random.multivariate_normal([1.0, 1.0], np.eye(2, 2), 50)
X2 = np.random.multivariate_normal([7.0, 9.0], np.eye(2, 2), 50)
X = np.vstack((X1, X2))
y = np.array([-1]*50+[1]*50)
res = lab3.svm_qp_primal_solver(X, y, 1)
x_min = np.min(X[:, 0])
x_max = np.max(X[:, 0])
a = res['w'][0]
b = res['w'][1]
c = res['w0']
print(a, b, c, x_min, x_max)
# Out:
#      pcost       dcost       gap    pres   dres
#  0: -9.5660e+01  1.5061e+02  7e+02  3e+00  7e+01
#  1:  4.2131e+01 -3.3437e+01  1e+02  3e-01  6e+00
#  2:  5.9511e+00 -4.1322e+00  1e+01  4e-02  8e-01
#  3:  3.0504e-01 -7.8068e-02  4e-01  2e-04  4e-03
#  4:  9.0870e-02  2.7514e-02  6e-02  2e-05  5e-04
#  5:  8.0617e-02  5.4132e-02  3e-02  6e-06  1e-04
#  6:  7.7162e-02  6.7520e-02  1e-02  6e-07  1e-05
#  7:  7.2412e-02  7.2150e-02  3e-04  2e-08  3e-07
#  8:  7.2284e-02  7.2282e-02  3e-06  2e-10  3e-09
#  9:  7.2283e-02  7.2283e-02  3e-08  2e-12  3e-11
# Optimal solution found.
# 0.204577765369 0.320490398125 -2.573898149942278 -1.61617281857 10.0032372544

# %%
reload(lab3)
lab3.visualize(X, y, res['w0'], res['w'])

# %%
reload(lab3)
res = lab3.svm_qp_dual_solver(X, y, 1)
x_min = np.min(X[:, 0])
x_max = np.max(X[:, 0])
a = res['w'][0]
b = res['w'][1]
c = res['w0']
print(a, b, c, x_min, x_max)
# Out:
#      pcost       dcost       gap    pres   dres
#  0: -4.1848e+00 -1.5076e+02  7e+02  2e+00  5e-14
#  1: -2.0175e+00 -6.4598e+01  1e+02  2e-01  3e-14
#  2: -2.3011e-01 -8.6954e+00  1e+01  2e-02  2e-14
#  3:  5.7446e-02 -3.2012e-01  4e-01  1e-04  5e-15
#  4: -2.8419e-02 -9.2439e-02  6e-02  1e-05  2e-15
#  5: -5.4366e-02 -8.1075e-02  3e-02  4e-06  1e-15
#  6: -6.7543e-02 -7.7206e-02  1e-02  4e-07  2e-15
#  7: -7.2150e-02 -7.2414e-02  3e-04  9e-09  2e-15
#  8: -7.2282e-02 -7.2284e-02  3e-06  1e-10  1e-15
#  9: -7.2283e-02 -7.2283e-02  3e-08  1e-12  2e-15
# Optimal solution found.
# 0.204577765369 0.320490398125 -2.573898149942279 -1.61617281857 10.0032372544

# %%
reload(lab3)
lab3.visualize(X, y, res['w0'], res['w'])

# %%
reload(lab3)
res = lab3.svm_qp_dual_solver(X, y, 1, gamma=0.2)
# Out:
#      pcost       dcost       gap    pres   dres
#  0: -2.2138e+00 -1.1958e+02  4e+02  1e+00  8e-16
#  1: -1.7144e-01 -4.4285e+01  4e+01  4e-15  5e-16
#  2: -2.8990e+00 -6.6598e+00  4e+00  3e-15  7e-16
#  3: -3.4371e+00 -4.3797e+00  9e-01  9e-16  3e-16
#  4: -3.6199e+00 -3.8394e+00  2e-01  5e-16  3e-16
#  5: -3.6764e+00 -3.7291e+00  5e-02  3e-16  2e-16
#  6: -3.6951e+00 -3.6993e+00  4e-03  3e-15  2e-16
#  7: -3.6971e+00 -3.6972e+00  1e-04  3e-15  3e-16
#  8: -3.6972e+00 -3.6972e+00  2e-06  2e-16  3e-16
# Optimal solution found.

# %%
reload(lab3)
lab3.visualize(X, y, res['w0'], res['w'], res['A'], gamma=0.2)

# %%
reload(lab3)
res = lab3.svm_liblinear_solver(X, y, 1, max_iter=1000)

# %%
reload(lab3)
lab3.visualize(X, y, res['w0'], res['w'])
